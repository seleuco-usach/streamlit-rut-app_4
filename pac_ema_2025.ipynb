# %%
import pyodbc
import pandas as pd
import numpy as np
from datetime import date

con_1 = pyodbc.connect(
    f"DRIVER={{ODBC Driver 17 for SQL Server}};"
    f"SERVER=158.170.66.56,{1433};"
    f"DATABASE=PROC01ESTUDIO;"
    f"UID=proceso;"
    f"PWD=Estudio.2024;")



pac_2025 = pd.read_sql("""SELECT *
            FROM PAC_2008_2025
            where ano = 2025""", con_1)

pac_2025_ema = pac_2025[['clave_ano',
          'n_de_horas_con_contrato_de_planta_indefinido', 
          'n_de_horas_con_contrato_a_contrata_plazo_fijo',
          'n_de_horas_con_contrato_a_honorarios',
          'sexo', 'total_horas','jce', 
          'jeraquia_categoria',
          'nivel_formacion_corr',
          'nivel_formacion_esp_med',
          'con_cat_jer']]


#pac_2025_ema['jeraquia_categoria']
pac_2025_ema['jerarquia'] = np.where(
    (pac_2025_ema['jeraquia_categoria'] == "ADJUNTO II") | 
    (pac_2025_ema['jeraquia_categoria'] == "ADJUNTO I") |
    (pac_2025_ema['jeraquia_categoria'] == "INSTRUCTOR") |
    (pac_2025_ema['jeraquia_categoria'] == "INSTRUCTOR II"), 
          "categorizados", "jerarquizados")

pac_2025_ema['planta'] = np.where(
    pac_2025_ema['n_de_horas_con_contrato_de_planta_indefinido']!=0,1,0)

pac_2025_ema['contrata'] = np.where(
    pac_2025_ema['n_de_horas_con_contrato_a_contrata_plazo_fijo']!=0,1,0)

pac_2025_ema['honorario'] = np.where(
    pac_2025_ema['n_de_horas_con_contrato_a_honorarios']!=0,1,0)

pac_2025_ema.to_clipboard()
pac_2025[['tipo_jornada', 'cargo_o_funcion_desemp']].to_clipboard()

#pac_2025['n_de_horas_con_contrato_a_contrata_plazo_fijo']
#pac_2025_ema.info()
#pac_2025_ema['jeraquia_categoria'].unique()
#pac_2025_ema['jerarquia']
#pac_2025['con_cat_jer']
####listado de tablas
#cursor_1 = con_1.cursor()
#cursor_1.execute("SELECT TABLE_NAME FROM INFORMATION_SCHEMA.\
 #                TABLES WHERE TABLE_TYPE = 'BASE TABLE';")


#for t in cursor_1.fetchall():
 #   print(t)
# Out:
# /tmp/ipykernel_2427408/600838623.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pac_2025 = pd.read_sql("""SELECT *
# /tmp/ipykernel_2427408/600838623.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pac_2025_ema['jerarquia'] = np.where(
# /tmp/ipykernel_2427408/600838623.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
